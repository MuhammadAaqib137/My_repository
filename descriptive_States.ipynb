# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('descriptive_statistics.csv')
df
# Out:
#     Unnamed: 0    ID  Building  Year of sale  Month of sale Type of property  \
# 0          NaN  1030         1        2005.0           11.0        Apartment
# 1          NaN  1029         1        2005.0           10.0        Apartment
# 2          NaN  2002         2        2007.0            7.0        Apartment
# 3          NaN  2031         2        2007.0           12.0        Apartment
# 4          NaN  1049         1        2004.0           11.0        Apartment
# ..         ...   ...       ...           ...            ...              ...
# 262        NaN  5044         5           NaN            NaN        Apartment
# 263        NaN  5047         5           NaN            NaN        Apartment
# 264        NaN  5048         5           NaN            NaN        Apartment
# 265        NaN  5050         5           NaN            NaN        Apartment
# 266        NaN  5051         5           NaN            NaN        Apartment
#
# ...

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#        ID  Building  Year of sale  Month of sale Type of property  Property #  \
# 0    1030         1        2005.0           11.0        Apartment          30
# 1    1029         1        2005.0           10.0        Apartment          29
# 2    2002         2        2007.0            7.0        Apartment           2
# 3    2031         2        2007.0           12.0        Apartment          31
# 4    1049         1        2004.0           11.0        Apartment          49
# ..    ...       ...           ...            ...              ...         ...
# 262  5044         5           NaN            NaN        Apartment          44
# 263  5047         5           NaN            NaN        Apartment          47
# 264  5048         5           NaN            NaN        Apartment          48
# 265  5050         5           NaN            NaN        Apartment          50
# 266  5051         5           NaN            NaN        Apartment          51
#
# ...

# %%
df['Gender'][df['Gender'].isna()]
# Out:
# 178    NaN
# 179    NaN
# 180    NaN
# 181    NaN
# 182    NaN
#       ...
# 262    NaN
# 263    NaN
# 264    NaN
# 265    NaN
# 266    NaN
# Name: Gender, Length: 89, dtype: object

# %%
df['Gender']=df['Gender'].fillna('Firm')

# %%
df['Gender']
# Out:
# 0         F
# 1         F
# 2         M
# 3         M
# 4         F
#        ...
# 262    Firm
# 263    Firm
# 264    Firm
# 265    Firm
# 266    Firm
# Name: Gender, Length: 267, dtype: object

# %%
count=df['ID'].groupby(df['Gender']).count()

# %%
count
# Out:
# Gender
# F        70
# Firm     89
# M       108
# Name: ID, dtype: int64

# %%
total=count.sum()

# %%
relative_frequency=round(count/total*100)

# %%
relative_frequency
# Out:
# Gender
# F       26.0
# Firm    33.0
# M       40.0
# Name: ID, dtype: float64

# %%
Gender=pd.DataFrame({'frequency':count,'relative_frequency':relative_frequency})

# %%
Gender
# Out:
#         frequency  relative_frequency
# Gender
# F              70                26.0
# Firm           89                33.0
# M             108                40.0

# %%
Gender['relative_frequency'].plot(xlabel='Pie Chart',ylabel=" ",kind='pie',subplots=True,legend=True)
# Out:
# array([<AxesSubplot:ylabel=' '>], dtype=object)

# %%
state_group=df.groupby('State').State.count()

# %%
df['State']=df['State'].fillna('None (abroad)')

# %%
df['State']
# Out:
# 0         California
# 1         California
# 2         California
# 3         California
# 4         California
#            ...
# 262    None (abroad)
# 263    None (abroad)
# 264    None (abroad)
# 265    None (abroad)
# 266    None (abroad)
# Name: State, Length: 267, dtype: object

# %%
state_group=df.groupby('State').State.count()

# %%
state_group
# Out:
# State
# Arizona           11
# California       119
# Colorado          11
# Kansas             1
# Nevada            17
# None (abroad)     86
# Oregon            11
# Utah               6
# Virginia           4
# Wyoming            1
# Name: State, dtype: int64

# %%
group_State
# Out:
# State          Frequency
# Arizona               11
# California           119
# Colorado              11
# Kansas                 1
# Nevada                17
# None (abroad)         86
# Oregon                11
# Utah                   6
# Virginia               4
# Wyoming                1

# %%
total=state_group.sum()

# %%
rel_freq=round(state_group/total*100)

# %%
rel_freq
# Out:
# Arizona           4.0
# California       45.0
# Colorado          4.0
# Kansas            0.0
# Nevada            6.0
# None (abroad)    32.0
# Oregon            4.0
# Utah              2.0
# Virginia          1.0
# Wyoming           0.0
# Name: State, dtype: float64

# %%
group_State=pd.DataFrame({'Frequency':state_group,'Relative Frequency':rel_freq})
group_State.columns.name="State"
group_State.index.name=None

# %%
group_State['Cumulative Frequency']=group_State['Relative Frequency'].cumsum()

# %%
group_State
# Out:
# State          Frequency  Relative Frequency  Cumulative Frequency
# Arizona               11                 4.0                   4.0
# California           119                45.0                  49.0
# Colorado              11                 4.0                  53.0
# Kansas                 1                 0.0                  53.0
# Nevada                17                 6.0                  59.0
# None (abroad)         86                32.0                  91.0
# Oregon                11                 4.0                  95.0
# Utah                   6                 2.0                  97.0
# Virginia               4                 1.0                  98.0
# Wyoming                1                 0.0                  98.0
